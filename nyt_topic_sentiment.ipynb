# %% [markdown]
# # Sentiment Analysis on NYT Topics

# %% [markdown]
# ## 1. Importing Data

# %%
import pandas as pd
import os

# Path to the folder containing the CSV files
folder_path = "data/nyt"

# Get a list of all CSV files in the folder
csv_files = [file for file in os.listdir(folder_path) if file.endswith('.csv')]

# Create an empty list to store data frames
dfs = []

# Loop through each CSV file and read it into a data frame
for file in csv_files:
    file_path = os.path.join(folder_path, file)
    df = pd.read_csv(file_path)
    dfs.append(df)

# Concatenate all data frames into one
result = pd.concat(dfs, ignore_index=True)

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16478 entries, 0 to 16477
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    16478 non-null  object
#  1   snippet  16478 non-null  object
#  2   date     16478 non-null  object
#  3   url      16478 non-null  object
# dtypes: object(4)
# memory usage: 515.1+ KB

# %%
result
# Out:
#                                                    title  \
# 0                               Feminism Lost. Now What?
# 1      Fish Seek Cooler Waters, Leaving Some Fisherme...
# 2      ‘Church Militant’ Theology Is Put to New, and ...
# 3      In Banning Ivory Trade, China Saw Benefits for...
# 4      Can Carbon Capture Technology Prosper Under Tr...
# ...                                                  ...
# 16473               The Coronavirus and Carbon Emissions
# 16474  Laurene Powell Jobs Is Putting Her Own Dent in...
# 16475  U.K. Court Blocks Heathrow Airport Expansion o...
# 16476  Which States Are Doing the Most Sustainable Bu...
# 16477  Fighting Coal Was Supposed to Lift Bloomberg. ...
#
#                                                  snippet        date  \
# 0      “It’s amazing to me the lightning speed at whi...  2016-12-30
# 1      Catch limits for fishermen are often based on ...  2016-12-30
# 2      Its use by a right-wing website and others has...  2016-12-30
# 3      The decision to bring the world’s largest ivor...  2017-01-02
# 4      Progress has come in fits and starts, but supp...  2017-01-02
# ...                                                  ...         ...
# 16473  Also this week, a contentious idea: tweaking o...  2020-02-26
# 16474  An interview with the 35th-richest person in t...  2020-02-27
# 16475  The Court of Appeal said the government failed...  2020-02-27
# 16476  Here’s a look at the leading states for LEED c...  2020-02-27
# 16477  The former New York mayor is “a victim of the ...  2020-02-28
#
#                                                      url
# 0      https://www.nytimes.com/2016/12/30/opinion/sun...
# 1      https://www.nytimes.com/2016/12/30/science/fis...
# 2      https://www.nytimes.com/2016/12/30/us/church-m...
# 3      https://www.nytimes.com/2017/01/02/world/asia/...
# 4      https://www.nytimes.com/2017/01/02/science/don...
# ...                                                  ...
# 16473  https://www.nytimes.com/2020/02/26/climate/nyt...
# 16474  https://www.nytimes.com/2020/02/27/business/la...
# 16475  https://www.nytimes.com/2020/02/27/world/europ...
# 16476  https://www.nytimes.com/2020/02/27/realestate/...
# 16477  https://www.nytimes.com/2020/02/28/climate/blo...
#
# [16478 rows x 4 columns]

# %%
nyt = result[['date', 'url', 'title', 'snippet']]

# %%
nyt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16478 entries, 0 to 16477
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   date     16478 non-null  object
#  1   url      16478 non-null  object
#  2   title    16478 non-null  object
#  3   snippet  16478 non-null  object
# dtypes: object(4)
# memory usage: 515.1+ KB

# %% [markdown]
# ## 2. Cleaning Data

# %% [markdown]
# ### 2.2. Converting Data Type

# %%
nyt = nyt.drop_duplicates()

# %%
nyt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13214 entries, 0 to 16471
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   date     13214 non-null  object
#  1   url      13214 non-null  object
#  2   title    13214 non-null  object
#  3   snippet  13214 non-null  object
# dtypes: object(4)
# memory usage: 516.2+ KB

# %%
nyt['date'] = pd.to_datetime(nyt['date']).dt.date

# %%
# retain only rows where date is between 2017-01-01 and 2020-01-31
mask = (nyt['date'] >= '2017-01-01') & (nyt['date'] <= '2020-01-31')
nyt = nyt.loc[mask]

# %%
nyt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12844 entries, 3 to 16424
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   date     12844 non-null  object
#  1   url      12844 non-null  object
#  2   title    12844 non-null  object
#  3   snippet  12844 non-null  object
# dtypes: object(4)
# memory usage: 501.7+ KB

# %% [markdown]
# ### 2.3. Cleaning Texts

# %%
import re

def text_light_clean(x):
    x = x.encode('ascii', 'ignore').decode()  # remove unicode characters
    x = re.sub(r'https*\S+', ' ', x) # remove links
    x = re.sub(r'http*\S+', ' ', x) 

    x = re.sub(r'\s{2,}', ' ', x) # Replace any sequence of two or more whitespace characters with a single space.
    x = re.sub(r'\s[^\w\s]\s', '', x) #  Remove any punctuation that is surrounded by whitespace characters.
    
    return x

# %%
nyt['text'] = nyt['title'] + ' ' + nyt['snippet']

# %%
nyt['clean_text'] = nyt.text.apply(text_light_clean)

# %%
nyt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12844 entries, 3 to 16424
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        12844 non-null  object
#  1   url         12844 non-null  object
#  2   title       12844 non-null  object
#  3   snippet     12844 non-null  object
#  4   text        12844 non-null  object
#  5   clean_text  12844 non-null  object
# dtypes: object(6)
# memory usage: 702.4+ KB

# %% [markdown]
# ## 3. Classifying Topic

# %%
from bertopic import BERTopic
from sklearn.feature_extraction.text import CountVectorizer
import time

start_time = time.time()

# we add this to remove stopwords, for lower volumes of data stopwords can cause issues
vectorizer_model = CountVectorizer(ngram_range=(1, 2), stop_words="english")

doc = nyt.clean_text.tolist()

topic_model = BERTopic(
    min_topic_size = 15,
    vectorizer_model=vectorizer_model,
    language='english', calculate_probabilities=True,
    low_memory=True,
    # automatically reduce number of topiccs
#     nr_topics="auto",
    verbose=True
)

topics, probs = topic_model.fit_transform(doc)

end_time = time.time()
time_taken_seconds = end_time - start_time
time_taken_minutes = time_taken_seconds / 60
print(f"Time taken: {time_taken_minutes:.2f} minutes")
# Out:
# Batches:   0%|          | 0/402 [00:00<?, ?it/s]
# 2023-03-08 15:03:24,069 - BERTopic - Transformed documents to Embeddings
# 2023-03-08 15:03:31,374 - BERTopic - Reduced dimensionality
# 2023-03-08 15:03:39,373 - BERTopic - Clustered reduced embeddings
# Time taken: 2.71 minutes

# %%
# min_topic_size=15, reduced topics
# topic_model.get_topic_info().head(30)
# Out:
#     Topic  Count                                       Name
# 0      -1   4942             -1_new_trump_climate_president
# 1       0    790            0_trump_pollution_emissions_air
# 2       1    770                 1_yankees_game_league_team
# 3       2    693                   2_art_fashion_museum_new
# 4       3    453      3_climate_climate change_change_paris
# 5       4    369              4_hurricane_puerto_storm_rico
# 6       5    298                   5_trade_china_xi_tariffs
# 7       6    283           6_afghan_saudi_syria_afghanistan
# 8       7    229               7_reading_books_contest_book
# 9       8    189              8_facebook_social_tech_google
# 10      9    175                    9_chef_warren_meat_food
# 11     10    156     10_wildfires_fires_california_wildfire
# 12     11    146   11_prime_minister_trudeau_prime minister
# 13     12    144                  12_coral_whales_sea_reefs
# 14     13    141            13_places_52_52 places_traveler
# 15     14    116            14_open_williams_tennis_federer
# 16     15    105  15_immigrants_migrants_border_immigration
# 17     16     98             16_police_man_officer_officers
# 18     17     97           17_epa_pruitt_scott_scott pruitt
# 19     18     90               18_plastic_waste_bags_straws
# 20     19     89          19_subway_congestion_transit_plan
# 21     20     85             20_couple_couple met_met_groom
# 22     21     85               21_tv_netflix_shows_tv shows
# 23     22     81           22_songs_new songs_playlist_hear
# 24     23     74        23_health_care_health care_medicaid
# 25     24     71                 24_tax_budget_tax cut_cuts
# 26     25     64               25_green_tiny_buildings_home
# 27     26     59    26_climate_students_protesters_activism
# 28     27     59      27_patients_parents_charlie gard_gard
# 29     28     58           28_korea_north_north korea_south

# %%
# min_topic_size=10, reduced topics
# topic_model.get_topic_info().head(30)
# Out:
#     Topic  Count                                        Name
# 0      -1   5344              -1_new_trump_climate_president
# 1       0   1921            0_trump_climate_president_change
# 2       1    633                  1_yankees_game_mets_injury
# 3       2    471            2_species_scientists_birds_coral
# 4       3    290                   3_art_museum_artists_film
# 5       4    263           4_hurricane_storm_harvey_flooding
# 6       5    222                     5_china_trade_xi_chinas
# 7       6    208                 6_restaurant_food_chef_meat
# 8       7    204                      7_fed_tax_rates_budget
# 9       8    198      8_facebook_tech_silicon_silicon valley
# 10      9    192      9_fashion_designer_fashion week_brands
# 11     10    181        10_books_reading_reads_reading great
# 12     11    173              11_police_man_officers_charged
# 13     12    159  12_wildfires_fires_california_firefighters
# 14     13    121     13_comments_writing_times_comments week
# 15     14    118             14_open_williams_tennis_federer
# 16     15    118     15_canada_trudeau_justin_justin trudeau
# 17     16    109   16_immigrants_migrants_border_immigration
# 18     17    106            17_macron_france_merkel_emmanuel
# 19     18    104   18_typhoon_cyclone_earthquake_philippines
# 20     19     98                19_women_gender_womens_metoo
# 21     20     94                 20_subway_new_city_new york
# 22     21     89                21_plastic_waste_bags_straws
# 23     22     88            22_pruitt_epa_scott_scott pruitt
# 24     23     86            23_puerto_rico_puerto rico_maria
# 25     24     85              24_couple_met_couple met_groom
# 26     25     84                 25_tesla_electric_cars_elon
# 27     26     74             26_52_places_52 places_traveler
# 28     27     72                27_tv_netflix_shows_tv shows
# 29     28     67  28_health_care_health care_affordable care

# %%
# min_topic_size=30, reduced topics
# topic_model.get_topic_info().head(30)
# Out:
#     Topic  Count                                               Name
# 0      -1   4718                        -1_new_trump_climate_change
# 1       0   5936                      0_trump_new_climate_president
# 2       1    550                       1_fashion_art_museum_artists
# 3       2    144                        2_restaurant_chef_food_cook
# 4       3    116                     3_open_williams_tennis_federer
# 5       4    100                     4_places_52_52 places_traveler
# 6       5     98                    5_epa_pruitt_scott_scott pruitt
# 7       6     88                    6_puerto_puerto rico_rico_maria
# 8       7     87                      7_couple_met_couple met_groom
# 9       8     80                 8_health_care_health care_medicaid
# 10      9     77                    9_songs_new songs_playlist_hear
# 11     10     76                       10_tv_netflix_shows_tv shows
# 12     11     70                11_fed_rates_federal reserve_powell
# 13     12     70                     12_tax_budget_tax cut_trillion
# 14     13     54  13_wedding_weddings_weeks wedding_wedding anno...
# 15     14     53                  14_wine_wines_producers_vineyards
# 16     15     53               15_colleges_students_college_schools
# 17     16     50        16_comments_prompts_invitation join_writing
# 18     17     43    17_dance_ballet_performances_dance performances
# 19     18     41        18_art_closing soon_shows closing_guide new
# 20     19     40                         19_plane_boeing_flight_max
# 21     20     38                      20_uber_ridehailing_ubers_ipo
# 22     21     30               21_pope_francis_pope francis_vatican
# 23     22     29                      22_refuge_arctic_drilling_oil
# 24     23     29                23_market_stock_stocks_stock market
# 25     24     29                    24_meat_milk_burgers_plantbased
# 26     25     28          25_greta_thunberg_greta thunberg_activist
# 27     26     25              26_weight_eating_weight loss_diabetes
# 28     27     25                  27_hong_hong kong_kong_protesters
# 29     28     24                    28_opioid_drug_opioids_epidemic

# %%
# min_topic_size=20, reduced topics
# topic_model.get_topic_info().head(30)
# Out:
#     Topic  Count                                         Name
# 0      -1   5053               -1_new_trump_president_climate
# 1       0    974       0_democrats_democratic_trump_president
# 2       1    791                   1_yankees_game_mets_league
# 3       2    436                2_hurricane_storm_puerto_rico
# 4       3    318      3_climate_climate change_change_science
# 5       4    256                    4_art_museum_artists_film
# 6       5    248                    5_afghan_saudi_syria_iran
# 7       6    203         6_fashion_designer_fashion week_mens
# 8       7    174                7_police_man_officers_officer
# 9       8    174               8_ice_heat_temperatures_arctic
# 10      9    156          9_reads_books_reading_reading great
# 11     10    154       10_wildfires_california_fires_wildfire
# 12     11    150             11_birds_species_forests_animals
# 13     12    149                 12_restaurant_chef_food_cook
# 14     13    145         13_brexit_immigrants_migrants_border
# 15     14    141                    14_coral_whales_sea_reefs
# 16     15    124             15_macron_france_emmanuel_french
# 17     16    124      16_canada_trudeau_justin_justin trudeau
# 18     17    113             17_pruitt_epa_scott_scott pruitt
# 19     18    109                 18_facebook_tech_google_data
# 20     19    108              19_open_williams_tennis_federer
# 21     20    107              20_52_places_52 places_traveler
# 22     21     96           21_plastic_waste_bags_plastic bags
# 23     22     91                22_subway_city_congestion_new
# 24     23     91  23_music_classical_classical music_broadway
# 25     24     84               24_couple_couple met_met_groom
# 26     25     78          25_fed_rates_powell_federal reserve
# 27     26     78             26_trade_tariffs_china_trade war
# 28     27     76                 27_tv_netflix_shows_tv shows
# 29     28     73          28_air_pollution_air pollution_smog

# %%
# min_topic_size=15
topic_model.get_topic_info().head(30)
# Out:
#      Topic  Count                                            Name
# 0       -1   5275                  -1_trump_new_president_climate
# 1        0    228            0_fashion_designer_wear_fashion week
# 2        1    217             1_reads_books_reading_reading great
# 3        2    217             2_hurricane_storm_harvey_hurricanes
# 4        3    178                      3_yankees_mets_injury_game
# ..     ...    ...                                             ...
# 135    134     16     134_ceos_councils_business leaders_advisory
# 136    135     16        135_solar_power_solar power_solar panels
# 137    136     16  136_buttigieg_pete_pete buttigieg_mr buttigieg
# 138    137     16             137_powell_yellen_fed_jerome powell
# 139    138     16     138_pompeo_mike pompeo_mike_secretary state
#
# [140 rows x 3 columns]

# %%
# min_topic_size=20
# topic_model.get_topic_info().head(30)
# Out:
#     Topic  Count                                       Name
# 0      -1   4807             -1_new_trump_climate_president
# 1       0    416          0_democratic_democrats_2020_biden
# 2       1    394           1_species_scientists_birds_coral
# 3       2    213                    2_china_trade_xi_chinas
# 4       3    209       3_fashion_designer_fashion week_wear
# 5       4    208            4_hurricane_storm_harvey_storms
# 6       5    196              5_police_man_officers_officer
# 7       6    179             6_facebook_tech_google_silicon
# 8       7    176                 7_yankees_mets_injury_game
# 9       8    168               8_art_museum_artists_museums
# 10      9    159                9_restaurant_chef_food_cook
# 11     10    155        10_trump_president_obama_presidents
# 12     11    147            11_ice_heat_temperatures_arctic
# 13     12    135   12_climate_climate change_change_science
# 14     13    131            13_52_places_52 places_traveler
# 15     14    125           14_macron_france_emmanuel_merkel
# 16     15    118  15_immigrants_border_migrants_immigration
# 17     16    117            16_open_williams_tennis_federer
# 18     17    112        17_warriors_nba_knicks_golden state
# 19     18    111  18_comments_writing_comments week_prompts
# 20     19    110  19_earthquake_typhoon_cyclone_philippines
# 21     20    106      20_tax_budget_trillion_infrastructure
# 22     21    104       21_afghan_taliban_afghanistan_killed
# 23     22    104          22_women_harassment_sexual_womens
# 24     23    101   23_climate_climate change_change_warming
# 25     24    100       24_nfl_patriots_quarterback_nfl week
# 26     25     99                 25_iran_syria_isis_iranian
# 27     26     94           26_pruitt_epa_scott_scott pruitt
# 28     27     93          27_subway_congestion_transit_plan
# 29     28     93               28_plastic_waste_bags_straws

# %%
# min_topic_size=10
# topic_model.get_topic_info().head(50)
# Out:
#     Topic  Count                                               Name
# 0      -1   4836                        -1_trump_new_climate_change
# 1       0    222               0_fashion_designer_wear_fashion week
# 2       1    217                       1_art_museum_artists_museums
# 3       2    176                         2_yankees_mets_injury_game
# 4       3    146      3_reading_reading great_great reads_reads web
# 5       4    136                  4_democrats_governor_orourke_beto
# 6       5    133                    5_macron_france_merkel_emmanuel
# 7       6    118                     6_open_williams_tennis_federer
# 8       7    106                 7_warriors_nba_knicks_golden state
# 9       8    103                      8_police_man_officers_officer
# 10      9    103                      9_film_movies_films_hollywood
# 11     10    102                   10_nfl_patriots_quarterback_bowl
# 12     11    101                 11_plastic_waste_bags_plastic bags
# 13     12    101                   12_trade_tariffs_china_trade war
# 14     13     98   13_climate_climate change_warming_global warming
# 15     14     98               14_afghan_taliban_afghanistan_killed
# 16     15     95          15_wildfires_fires_california_californias
# 17     16     94                    16_tesla_electric_cars_vehicles
# 18     17     93          17_immigrants_migrants_border_immigration
# 19     18     92                   18_pruitt_epa_scott_scott pruitt
# 20     19     87                     19_couple_couple met_met_groom
# 21     20     87                   20_puerto_rico_puerto rico_maria
# 22     21     83                      21_cup_world cup_soccer_world
# 23     22     83             22_impeachment_mueller_democrats_house
# 24     23     82                23_obama_trump_president_presidents
# 25     24     80         24_care_health_health care_affordable care
# 26     25     75           25_music_classical_classical music_opera
# 27     26     74                    26_52_travel_52 places_traveler
# 28     27     72                       27_tv_netflix_tv shows_shows
# 29     28     68                         28_epa_agency_rules_plants
# 30     29     67             29_volkswagen_diesel_emissions_scandal
# 31     30     67                30_air_pollution_air pollution_smog
# 32     31     62                    31_russia_russian_putin_russias
# 33     32     61           32_olympics_olympic_gold_winter olympics
# 34     33     60                   33_new songs_songs_playlist_hear
# 35     34     57   34_general assembly_assembly_united nations_nato
# 36     35     56              35_patients_parents_gard_charlie gard
# 37     36     55                 36_brazils_bolsonaro_amazon_brazil
# 38     37     55  37_wedding_weddings_weeks wedding_wedding anno...
# 39     38     54                             38_energy_oil_coal_gas
# 40     39     54               39_colleges_college_students_schools
# 41     40     53                         40_water_flint_lead_crisis
# 42     41     53                  41_wine_wines_producers_vineyards
# 43     42     51            42_students_protesters_climate_protests
# 44     43     51                   43_korea_north_north korea_south
# 45     44     50                       44_tiny_urban_green_rooftops
# 46     45     49                      45_chef_restaurant_chefs_food
# 47     46     48        46_art_closing soon_shows closing_art shows
# 48     47     48    47_dance_ballet_performances_dance performances
# 49     48     48            48_colbert_kimmel_stephen colbert_jimmy

# %%
import pickle

# save the model
with open('model/topic_model_nyt.pkl', 'wb') as f:
    pickle.dump(topic_model, f)
# Out:
# /Users/marcelzhang/opt/anaconda3/lib/python3.9/site-packages/scipy/sparse/_index.py:125: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)

# %%
# topic_model.reduce_topics(doc, nr_topics="auto")

# %%
# assign topic labels to every text
nyt['topic'] = topics

# filter out the outliers
# nyt = nyt[nyt['topic'] != -1]

# %% [markdown]
# ## 4. Analyzing Sentiment

# %% [markdown]
# ### 4.1. Getting Sentiment Scores for Texts

# %%
## Using roberta
from transformers import AutoModelForSequenceClassification
from transformers import TFAutoModelForSequenceClassification
from transformers import AutoTokenizer, AutoConfig
import numpy as np
from scipy.special import softmax

MODEL = f"cardiffnlp/twitter-roberta-base-sentiment-latest"
tokenizer = AutoTokenizer.from_pretrained(MODEL)
config = AutoConfig.from_pretrained(MODEL)
model = AutoModelForSequenceClassification.from_pretrained(MODEL)
# Out:
# Some weights of the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment-latest were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
# Define a function to apply the sentiment analyzer to a given text
def get_sentiment_scores(text):
    encoded_input = tokenizer(text, return_tensors='pt')
    output = model(**encoded_input)
    scores = output[0][0].detach().numpy()
    scores = softmax(scores)

    # Define weights for negative, neutral, and positive sentiments
    weights = np.array([-1, 0, 1])

    # Compute the compound sentiment score
    compound_score = np.dot(scores, weights)
    
    return compound_score

# %%
# Test on a given text
text = "Donald Trump better pray there is no global warming, because he's one easily melted precious snowflake."
get_sentiment_scores(text)
# Out:
# -0.859273349866271

# %%
from tqdm import tqdm

tqdm.pandas()

start_time = time.time()

# Apply the sentiment analyzer to each text
nyt["sentiment"] = nyt["text"].progress_apply(get_sentiment_scores)

end_time = time.time()
time_taken_seconds = end_time - start_time
time_taken_minutes = time_taken_seconds / 60
print(f"Time taken: {time_taken_minutes:.2f} minutes")
# Out:
# 100%|█████████████████████████████████████| 12844/12844 [24:47<00:00,  8.63it/s]
# Time taken: 24.79 minutes

# %%
nyt.to_csv('data/nyt_text_sentiment.csv', index=False)

# %% [markdown]
# ### 4.2. Getting Sentiment Scores for Topics

# %%
# Calculate the average sentiment per topic
topic_sen = nyt.groupby('topic')['sentiment'].mean().round(2).reset_index()
topic_sen.columns = ['Topic', 'Avg_Sentiment']

# Merge the topic counts and average sentiment dataframes
topic_info_sen = pd.merge(topic_model.get_topic_info(), topic_sen, on='Topic')

# %%
topic_info_sen
# Out:
#      Topic  Count                                            Name  \
# 0       -1   5275                  -1_trump_new_president_climate
# 1        0    228            0_fashion_designer_wear_fashion week
# 2        1    217             1_reads_books_reading_reading great
# 3        2    217             2_hurricane_storm_harvey_hurricanes
# 4        3    178                      3_yankees_mets_injury_game
# ..     ...    ...                                             ...
# 135    134     16     134_ceos_councils_business leaders_advisory
# 136    135     16        135_solar_power_solar power_solar panels
# 137    136     16  136_buttigieg_pete_pete buttigieg_mr buttigieg
# 138    137     16             137_powell_yellen_fed_jerome powell
# 139    138     16     138_pompeo_mike pompeo_mike_secretary state
#
#      Avg_Sentiment
# 0            -0.09
# 1             0.29
# 2             0.27
# 3            -0.32
# 4             0.05
# ..             ...
# 135          -0.32
# 136           0.17
# 137           0.10
# 138           0.14
# 139          -0.11
#
# [140 rows x 4 columns]

# %%
topic_info_sen.to_csv('data/nyt_topic_sentiment.csv', index=False)

# %%
topic_info_sen.head(30)
# Out:
#     Topic  Count                                       Name  Avg_Sentiment
# 0      -1   5066                -1_new_trump_climate_change          -0.09
# 1       0    794              0_trump_china_president_trade          -0.22
# 2       1    770                    1_art_fashion_new_songs           0.23
# 3       2    707                 2_yankees_game_mets_league           0.08
# 4       3    397          3_hurricane_storm_flooding_harvey          -0.43
# 5       4    302    4_climate_climate change_change_warming          -0.19
# 6       5    238         5_afghan_afghanistan_taliban_syria          -0.42
# 7       6    204              6_reading_reads_books_contest           0.38
# 8       7    161      7_wildfires_fires_california_wildfire          -0.52
# 9       8    155     8_minister_prime_prime minister_brexit          -0.21
# 10      9    154                9_facebook_tech_google_data          -0.18
# 11     10    150               10_restaurant_chef_food_cook           0.34
# 12     11    123            11_open_williams_tennis_federer           0.09
# 13     12    113  12_immigrants_border_migrants_immigration          -0.43
# 14     13    111            13_52_places_52 places_traveler           0.46
# 15     14    109                  14_whales_coral_sea_reefs          -0.19
# 16     15     97             15_police_man_officers_officer          -0.66
# 17     16     89                16_tesla_electric_cars_elon           0.15
# 18     17     89           17_puerto_puerto rico_rico_maria          -0.36
# 19     18     89           18_pruitt_epa_scott_scott pruitt          -0.26
# 20     19     88               19_plastic_waste_bags_straws          -0.20
# 21     20     87             20_couple_couple met_met_groom           0.15
# 22     21     82          21_subway_congestion_transit_plan          -0.23
# 23     22     77      22_paris_climate_paris climate_accord          -0.09
# 24     23     76               23_tv_netflix_shows_tv shows           0.36
# 25     24     76        24_air_pollution_air pollution_smog          -0.52
# 26     25     75        25_fed_rates_powell_federal reserve          -0.01
# 27     26     74        26_health_care_health care_medicaid          -0.23
# 28     27     68             27_tax_budget_tax cut_trillion          -0.17
# 29     28     64  28_patients_hospital_parents_charlie gard          -0.29
