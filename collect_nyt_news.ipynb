# %% [markdown]
# ## Loading credentials from another config file

# %%
from config import NYT_API_KEY

# %% [markdown]
# ## Starting with New York Times API

# %%
import requests
from config import NYT_API_KEY

# %%
# %pip install --upgrade pynytimes
from pynytimes import NYTAPI

api_key = NYT_API_KEY

nyt = NYTAPI(api_key, parse_dates=True)

# %%
climate_keywords = ['climate change',
                    'sustainability', 
                    'pollution', 
                    'biodiversity', 
                    'natural disaster', 
                    'environmental policy']

# %%
#Import datetime function from datetime library which allows us to create a datetime object

from datetime import datetime, timedelta
import pandas as pd

#Set up start and end date objects

begin = datetime(2016, 12, 31)

end = datetime(2020, 2, 29)

# set range of dates per 7 days
date_range = pd.date_range(start=begin, end=end, freq='1SM')

date_ranges = [(date_range[i], date_range[i+1]-timedelta(days=1)) for i in range(len(date_range)-1)]

#Create dictionary containing dates data
date_dict = {"begin":begin, "end":end}

#Create options dictionary
options_dict = {
    #Sort from earliest to latest
    "sort": "oldest",
    # Return only articles from New York Times, filters out other sources such as AP and Reuters
    "sources": ["New York Times"],
    # Return only straight-forward news in the form of articles
    "type_of_material": ["News Analysis", "News", "Article"],    
}

# %%
import time

articles = []

for keyword in climate_keywords:
    for date_range in date_ranges:
        query = keyword
        dates = {"begin": date_range[0], "end": date_range[1]}
        response = nyt.article_search(query=query, dates=dates, results=50, options=options_dict)
        current_time = time.strftime('%H:%M:%S')
        
        print(f'{keyword}: {date_range[0]} - {date_range[1]} n_article = {len(response)} {current_time}')
        
        articles += response
        time.sleep(1)
# Out:
# ---------------------------------------------------------------------------
# MaxRetryError                             Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/adapters.py:440, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     439 if not chunked:
# --> 440     resp = conn.urlopen(
#     441         method=request.method,
#     442         url=url,
#     443         body=request.body,
#     444         headers=request.headers,
#     445         redirect=False,
#     446         assert_same_host=False,
#     447         preload_content=False,
#     448         decode_content=False,
#     449         retries=self.max_retries,
#     450         timeout=timeout
#     451     )
#     453 # Send the request.
#     454 else:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:876, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     875     log.debug("Retry: %s", url)
# --> 876     return self.urlopen(
#     877         method,
#     878         url,
#     879         body,
#     880         headers,
#     881         retries=retries,
#     882         redirect=redirect,
#     883         assert_same_host=assert_same_host,
#     884         timeout=timeout,
#     885         pool_timeout=pool_timeout,
#     886         release_conn=release_conn,
#     887         chunked=chunked,
#     888         body_pos=body_pos,
#     889         **response_kw
#     890     )
#     892 return response
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:876, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     875     log.debug("Retry: %s", url)
# --> 876     return self.urlopen(
#     877         method,
#     878         url,
#     879         body,
#     880         headers,
#     881         retries=retries,
#     882         redirect=redirect,
#     883         assert_same_host=assert_same_host,
#     884         timeout=timeout,
#     885         pool_timeout=pool_timeout,
#     886         release_conn=release_conn,
#     887         chunked=chunked,
#     888         body_pos=body_pos,
#     889         **response_kw
#     890     )
#     892 return response
#
#     [... skipping similar frames: HTTPConnectionPool.urlopen at line 876 (7 times)]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:876, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     875     log.debug("Retry: %s", url)
# --> 876     return self.urlopen(
#     877         method,
#     878         url,
#     879         body,
#     880         headers,
#     881         retries=retries,
#     882         redirect=redirect,
#     883         assert_same_host=assert_same_host,
#     884         timeout=timeout,
#     885         pool_timeout=pool_timeout,
#     886         release_conn=release_conn,
#     887         chunked=chunked,
#     888         body_pos=body_pos,
#     889         **response_kw
#     890     )
#     892 return response
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:866, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     865 try:
# --> 866     retries = retries.increment(method, url, response=response, _pool=self)
#     867 except MaxRetryError:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/util/retry.py:592, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     591 if new_retry.is_exhausted():
# --> 592     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     594 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='api.nytimes.com', port=443): Max retries exceeded with url: /svc/search/v2/articlesearch.json?api-key=GVkGbphR0Jr43uoaaF5t3bsitHvwMju2&sort=oldest&sources=New+York+Times&fq=type_of_material%3A%28%22News+Analysis%22+%22News%22+%22Article%22%29&begin_date=20180630&end_date=20180714&q=climate+change&page=0 (Caused by ResponseError('too many 429 error responses'))
#
# During handling of the above exception, another exception occurred:
#
# RetryError                                Traceback (most recent call last)
# Input In [6], in <cell line: 5>()
#       7 query = keyword
#       8 dates = {"begin": date_range[0], "end": date_range[1]}
# ----> 9 response = nyt.article_search(query=query, dates=dates, results=50, options=options_dict)
#      10 current_time = time.strftime('%H:%M:%S')
#      12 print(f'{keyword}: {date_range[0]} - {date_range[1]} n_article = {len(response)} {current_time}')
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pynytimes/api.py:726, in NYTAPI.article_search(self, query, dates, options, results)
#     723     _options["q"] = query
#     725 # Set result list and add request as much data as needed
# --> 726 result = self.__article_search_load_data(results, _options)
#     728 # Parse and return results
#     729 parsed_result = self.__parse_dates(result, "rfc3339", ["pub_date"])
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pynytimes/api.py:666, in NYTAPI.__article_search_load_data(self, results, options)
#     664 location = ["response"]
#     665 # Load data and raise error if there's and error status
# --> 666 res: dict[str, Any] = self.__load_data(  # type:ignore
#     667     url=BASE_ARTICLE_SEARCH, options=options, location=location
#     668 )
#     670 # Parse results and append them to results list
#     671 result += res.get("docs")  # type:ignore
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pynytimes/api.py:217, in NYTAPI.__load_data(self, url, options, location)
#     213 params.update(options or {})  # add empty list if None
#     215 # Load the data from the API, raise error if there's an invalid status
#     216 # code
# --> 217 res = self.session.get(
#     218     f"{self.protocol}{url}",
#     219     params=params,
#     220     timeout=TIMEOUT,
#     221 )
#     223 raise_for_status(res)
#     224 parsed_res: dict[str, Any] = res.json()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py:542, in Session.get(self, url, **kwargs)
#     534 r"""Sends a GET request. Returns :class:`Response` object.
#     535
#     536 :param url: URL for the new :class:`Request` object.
#     537 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     538 :rtype: requests.Response
#     539 """
#     541 kwargs.setdefault('allow_redirects', True)
# --> 542 return self.request('GET', url, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py:529, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     524 send_kwargs = {
#     525     'timeout': timeout,
#     526     'allow_redirects': allow_redirects,
#     527 }
#     528 send_kwargs.update(settings)
# --> 529 resp = self.send(prep, **send_kwargs)
#     531 return resp
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py:645, in Session.send(self, request, **kwargs)
#     642 start = preferred_clock()
#     644 # Send the request
# --> 645 r = adapter.send(request, **kwargs)
#     647 # Total elapsed time of the request (approximately)
#     648 elapsed = preferred_clock() - start
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/adapters.py:510, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     507         raise ConnectTimeout(e, request=request)
#     509 if isinstance(e.reason, ResponseError):
# --> 510     raise RetryError(e, request=request)
#     512 if isinstance(e.reason, _ProxyError):
#     513     raise ProxyError(e, request=request)
#
# RetryError: HTTPSConnectionPool(host='api.nytimes.com', port=443): Max retries exceeded with url: /svc/search/v2/articlesearch.json?api-key=GVkGbphR0Jr43uoaaF5t3bsitHvwMju2&sort=oldest&sources=New+York+Times&fq=type_of_material%3A%28%22News+Analysis%22+%22News%22+%22Article%22%29&begin_date=20180630&end_date=20180714&q=climate+change&page=0 (Caused by ResponseError('too many 429 error responses'))

# %%
len(articles)

# %%
# articles = nyt.article_search(
#     query = "environment",
#     results = 100,
#     dates =date_dict,
#     options = options_dict)

# %%
# create an empty list to hold dictionaries of article data
article_data = []

# iterate over articles and add relevant data to list of dictionaries
for article in articles:
    # get the publication date as a datetime object
    pub_date = article['pub_date']
    
    # convert datetime object to string in YYYY-MM-DD format
    pub_date_str = pub_date.strftime('%Y-%m-%d')
    
    # add relevant data to dictionary
    article_data.append({
        'title': article['headline']['main'],
        'snippet': article['abstract'],
        'date': pub_date_str,
        'url': article['web_url']
    })

# create dataframe from list of dictionaries
nyt_df = pd.DataFrame(article_data)

# set the order of columns in the dataframe
nyt_df = nyt_df[['title', 'snippet', 'date', 'url']]

# %%
nyt_df
# Out:
#                                                 title  \
# 0   18 Memorable People We Met Across the Country ...
# 1                   Four Questions for the Year Ahead
# 2   New E.P.A. Plan Could Free Coal Plants to Rele...
# 3   ‘It’s Not Going Away’: 2 Years of Documenting ...
# 4   ‘You Control Nothing’: House Republicans Brace...
# 5   Bangladesh’s Leader Wins a Third Term but Oppo...
# 6   2020 Candidates Are Lining Up. Which Democrat ...
# 7        In San Francisco, a Younger Sibling Acts Out
# 8   Along a Road of Sorrow, a Toddler Lost Her Nam...
# 9   The South Asian Artists Making Their Mark on t...
# 10  18 Memorable People We Met Across the Country ...
# 11              Athletes Who Changed the Game in 2018
# 12                 How to Recycle Your Christmas Tree
# 13  Carlos Ghosn’s Daughters See a Nissan Revolt B...
# 14  How Airlines Are Catering to Their Smallest Cu...
# 15  China Thwarts U.S. Effort to Promote American ...
# 16  Aaron Rodgers Is Hurt and the Packers Are Humi...
# 17  In Orange County, a Republican Fortress Turns ...
# 18  ‘I Have Seen Many Crises’: Steel Magnate Stand...
# 19  New E.P.A. Plan Could Free Coal Plants to Rele...
# 20  How an Explosion (Not Aliens) Turned New York’...
# 21         Hearing Loss Threatens Mind, Life and Limb
# 22      A Young Singer Takes the Opera World by Storm
# 23  18 Memorable People We Met Across the Country ...
# 24  The Power of One Family’s Story, More Than a Y...
# 25  Guatemala Cautious on Young Migrants’ Deaths, ...
#
#                                               snippet        date  \
# 0   In a chaotic year, these 18 people left indeli...  2018-12-28
# 1   Here are four important unsettled issues for 2...  2018-12-28
# 2   The proposal could set a precedent reaching fa...  2018-12-28
# 3   Race/Related is a weekly newsletter focused on...  2018-12-29
# 4   Most Republican representatives are about to e...  2018-12-29
# 5   In a vote with widespread irregularities and i...  2018-12-31
# 6   Democrats are in a moment of transition, grapp...  2018-12-31
# 7   At Angler, sister to the three-Michelin-star S...  2018-12-28
# 8   A roadside bomb wiped out a family in Afghanis...  2018-12-28
# 9   Women from India, Pakistan and beyond are fina...  2018-12-28
# 10  In a chaotic year, these 18 people left indeli...  2018-12-28
# 11  Beyond spectacular achievement, these athletes...  2018-12-28
# 12  You don’t want your tree to end up in a landfi...  2018-12-28
# 13  Breaking a silence, Caroline and Maya Ghosn sa...  2018-12-29
# 14  More and more airlines are turning their atten...  2018-12-29
# 15  The Chinese authorities blocked activities of ...  2018-12-30
# 16  Rodgers left the game with a concussion to end...  2018-12-30
# 17  The Democratic sweep in Orange County is the l...  2018-12-31
# 18  Despite being hurt by inflation, a falling cur...  2018-12-31
# 19  The proposal could set a precedent reaching fa...  2018-12-28
# 20  The Men in Black and the Ghostbusters did not ...  2018-12-28
# 21  Poor hearing is not just an annoying inconveni...  2018-12-31
# 22  Anita Rachvelishvili is “without doubt the bes...  2018-12-28
# 23  In a chaotic year, these 18 people left indeli...  2018-12-28
# 24  Readers of the New York Times Magazine article...  2018-12-31
# 25  Guatemalan officials’ courting of the Trump ad...  2018-12-28
#
#                                                   url
# 0   https://www.nytimes.com/2018/12/28/us/18-memor...
# 1   https://www.nytimes.com/2018/12/28/business/fo...
# 2   https://www.nytimes.com/2018/12/28/climate/mer...
# 3   https://www.nytimes.com/2018/12/29/us/hate-cri...
# 4   https://www.nytimes.com/2018/12/29/us/politics...
# 5   https://www.nytimes.com/2018/12/31/world/asia/...
# 6   https://www.nytimes.com/2018/12/31/us/politics...
# 7   https://www.nytimes.com/2018/12/28/travel/in-s...
# 8   https://www.nytimes.com/2018/12/28/world/asia/...
# 9   https://www.nytimes.com/2018/12/28/t-magazine/...
# 10  https://www.nytimes.com/2018/12/28/us/18-memor...
# 11  https://www.nytimes.com/2018/12/28/sports/6-at...
# 12  https://www.nytimes.com/2018/12/28/science/chr...
# 13  https://www.nytimes.com/2018/12/29/business/ca...
# 14  https://www.nytimes.com/2018/12/29/travel/how-...
# 15  https://www.nytimes.com/2018/12/30/world/asia/...
# 16  https://www.nytimes.com/2018/12/30/sports/aaro...
# 17  https://www.nytimes.com/2018/12/31/us/orange-c...
# 18  https://www.nytimes.com/2018/12/31/business/ec...
# 19  https://www.nytimes.com/2018/12/28/climate/mer...
# 20  https://www.nytimes.com/2018/12/28/nyregion/tr...
# 21  https://www.nytimes.com/2018/12/31/well/live/h...
# 22  https://www.nytimes.com/2018/12/28/arts/music/...
# 23  https://www.nytimes.com/2018/12/28/us/18-memor...
# 24  https://www.nytimes.com/2018/12/31/reader-cent...
# 25  https://www.nytimes.com/2018/12/28/world/ameri...

# %%
nyt_df.to_csv('data/nyt_20181228_20181231.csv', index=False)

# %%
articles[0]['abstract']

# %%
articles[0]['web_url']

# %%
articles[0]['headline']['main']

# %%
articles[0]['pub_date'].strftime('%Y-%m-%d')

# %%
articles[0]
