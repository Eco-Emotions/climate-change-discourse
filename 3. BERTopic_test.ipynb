# %%
#%pip install bertopic

# %%
from bertopic import BERTopic
import pandas as pd
from tqdm import tqdm

# %%
import os

# Path to the folder containing the CSV files
folder_path = "data/media"

# Get a list of all CSV files in the folder
csv_files = [file for file in os.listdir(folder_path) if file.endswith('.csv')]

# Create an empty list to store data frames
dfs = []

# Loop through each CSV file and read it into a data frame
for file in csv_files:
    file_path = os.path.join(folder_path, file)
    df = pd.read_csv(file_path)
    dfs.append(df)

# Concatenate all data frames into one
result = pd.concat(dfs, ignore_index=True)

# %%
result_slim = result.loc[:, ['MatchDateTime', 'Station', 'Snippet']]

# %%
media_20 = result_slim.sample(frac=0.2)

# %%
media_20.Snippet
# Out:
# 46046    you will spend a lot of 2020 working on the cl...
# 15713    carbon tax. no, i think there are very good an...
# 18184    (burke) otherwise known as sand trap scavenger...
# 44070    responsibilities when it comes to climate chan...
# 7381     regimes to refuse to welcome a global climate ...
#                                ...
# 1293     there is no climate change. if it's hot out, t...
# 1810     how climate change denial is destroying our po...
# 21392    towards a more sustainable form of energy, red...
# 24708    humans have some type of impact on climate cha...
# 10569    leyland: right after the election when you wou...
# Name: Snippet, Length: 10014, dtype: object

# %% [markdown]
# # Prepossessing Data

# %%
import nltk
from nltk.corpus import stopwords
import string

# Download NLTK stopwords and punkt
nltk.download('stopwords')
nltk.download('punkt')

# Define function to preprocess text
def preprocess_text(text):
    # Remove punctuation
    text = text.translate(str.maketrans('', '', string.punctuation))
    # Convert to lowercase
    text = text.lower()
    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    
    
    words = nltk.word_tokenize(text)
    words = [word for word in words if word not in stop_words]
    # Remove duplicates
    words = list(set(words))
    # Join words back into a string
    text = ' '.join(words)
    return text
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/marcelzhang/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/marcelzhang/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# Define function to preprocess text
def preprocess_text_no_token(text):
    # Remove punctuation
    text = text.translate(str.maketrans('', '', string.punctuation))
    # Convert to lowercase
    text = text.lower()
    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    
    words = text.split()
    words = [word for word in words if word not in stop_words]
    # Remove duplicates
    words = list(set(words))
    # Join words back into a string
    text = ' '.join(words)
    return text

# %%
# Apply preprocess_text_no_token to the DataFrame
media_20['Preprocessed_Snippet'] = media_20['Snippet'].apply(preprocess_text_no_token)

# %%
media_20
# Out:
#              MatchDateTime  Station  \
# 46046  12/30/2019 12:09:18  BBCNEWS
# 15713   4/23/2019 14:44:48      CNN
# 18184   1/19/2020 12:48:39    MSNBC
# 44070     9/6/2017 3:51:58  BBCNEWS
# 7381   12/10/2018 21:55:52      CNN
# ...                    ...      ...
# 1293     1/30/2018 0:46:16    MSNBC
# 1810   11/24/2018 13:05:40      CNN
# 21392   5/30/2017 13:52:26    MSNBC
# 24708    8/30/2019 4:08:33    MSNBC
# 10569   2/11/2017 17:34:37  FOXNEWS
#
#                                                  Snippet  \
# 46046  you will spend a lot of 2020 working on the cl...
# 15713  carbon tax. no, i think there are very good an...
# 18184  (burke) otherwise known as sand trap scavenger...
# 44070  responsibilities when it comes to climate chan...
# 7381   regimes to refuse to welcome a global climate ...
# ...                                                  ...
# 1293   there is no climate change. if it's hot out, t...
# 1810   how climate change denial is destroying our po...
# 21392  towards a more sustainable form of energy, red...
# 24708  humans have some type of impact on climate cha...
# 10569  leyland: right after the election when you wou...
#
#                                     Preprocessed_Snippet
# 46046  working say like summit slowburn spend financi...
# 15713  answers move quickly ton cap things tax renewa...
# 18184  weve change known otherwise trap twentyninth s...
# 44070  change us cannot world responsibilities techno...
# 7381   change conclusion warns landmark effects refus...
# ...                                                  ...
# 1293   know change data deal scientists nan lying sli...
# 1810   change man report sitting destroying say denia...
# 21392  run change form compliance companies footprint...
# 24708  change natural type region extent put promoted...
# 10569  change election right remember moved henderson...
#
# [10014 rows x 4 columns]

# %%
# Apply preprocess_text to the DataFrame
media_20['Tokenized_Snippet'] = media_20['Snippet'].apply(preprocess_text)

# %%
media_20
# Out:
#              MatchDateTime  Station  \
# 46046  12/30/2019 12:09:18  BBCNEWS
# 15713   4/23/2019 14:44:48      CNN
# 18184   1/19/2020 12:48:39    MSNBC
# 44070     9/6/2017 3:51:58  BBCNEWS
# 7381   12/10/2018 21:55:52      CNN
# ...                    ...      ...
# 1293     1/30/2018 0:46:16    MSNBC
# 1810   11/24/2018 13:05:40      CNN
# 21392   5/30/2017 13:52:26    MSNBC
# 24708    8/30/2019 4:08:33    MSNBC
# 10569   2/11/2017 17:34:37  FOXNEWS
#
#                                                  Snippet  \
# 46046  you will spend a lot of 2020 working on the cl...
# 15713  carbon tax. no, i think there are very good an...
# 18184  (burke) otherwise known as sand trap scavenger...
# 44070  responsibilities when it comes to climate chan...
# 7381   regimes to refuse to welcome a global climate ...
# ...                                                  ...
# 1293   there is no climate change. if it's hot out, t...
# 1810   how climate change denial is destroying our po...
# 21392  towards a more sustainable form of energy, red...
# 24708  humans have some type of impact on climate cha...
# 10569  leyland: right after the election when you wou...
#
#                                     Preprocessed_Snippet  \
# 46046  working say like summit slowburn spend financi...
# 15713  answers move quickly ton cap things tax renewa...
# 18184  weve change known otherwise trap twentyninth s...
# 44070  change us cannot world responsibilities techno...
# 7381   change conclusion warns landmark effects refus...
# ...                                                  ...
# 1293   know change data deal scientists nan lying sli...
# 1810   change man report sitting destroying say denia...
# 21392  run change form compliance companies footprint...
# 24708  change natural type region extent put promoted...
# 10569  change election right remember moved henderson...
#
#                                        Tokenized_Snippet
# 46046  working say like summit slowburn spend financi...
# 15713  answers move quickly ton cap things tax renewa...
# 18184  weve change known otherwise trap twentyninth s...
# 44070  change us world responsibilities technology co...
# 7381   change conclusion warns landmark effects refus...
# ...                                                  ...
# 1293   know change data deal scientists nan lying sli...
# 1810   change man report sitting destroying say denia...
# 21392  run change form compliance companies footprint...
# 24708  change natural type region extent put promoted...
# 10569  change election right remember moved henderson...
#
# [10014 rows x 5 columns]

# %% [markdown]
# # Fitting BERTopic

# %% [markdown]
# ## Original Text

# %%
text = media_20.Snippet.tolist()

# %%
topic_model = BERTopic(embedding_model="all-MiniLM-L6-v2")

# %%
topics, probs = topic_model.fit_transform(text)

# %%
topic_model.get_topic_info()
# Out:
#      Topic  Count                                   Name
# 0       -1   4606                  -1_the_and_to_climate
# 1        0    313      0_paris_agreement_trump_president
# 2        1    291    1_london_police_protests_protesters
# 3        2    226  2_weather_temperatures_extreme_record
# 4        3    219                     3_he_him_his_think
# ..     ...    ...                                    ...
# 108    107     11         107_primary_humans_wrong_cause
# 109    108     11          108_wine_beer_english_england
# 110    109     11  109_market_moreover_failure_economies
# 111    110     11      110_filmed_dinner_suspended_field
# 112    111     10         111_south_incheon_report_korea
#
# [113 rows x 3 columns]

# %% [markdown]
# ## Preprocessed Text

# %%
text_pre = media_20.Preprocessed_Snippet.tolist()

# %%
topic_model_pre = BERTopic(embedding_model="all-MiniLM-L6-v2")

# %%
topics_pre, probs_pre = topic_model_pre.fit_transform(text_pre)

# %%
topic_model_pre.get_topic_info()
# Out:
#      Topic  Count                                Name
# 0       -1   4788    -1_climate_change_global_warming
# 1        0    353  0_paris_agreement_accord_president
# 2        1    332       1_care_health_gun_immigration
# 3        2    291    2_london_police_protests_protest
# 4        3    173      3_children_school_schools_kids
# ..     ...    ...                                 ...
# 108    107     11  107_fracking_shale_underground_ban
# 109    108     10     108_parties_voters_debacle_lose
# 110    109     10      109_tillerson_rex_kelly_russia
# 111    110     10      110_fuels_dioxide_fossil_avoid
# 112    111     10        111_amazon_tool_flames_fires
#
# [113 rows x 3 columns]

# %%
topic_model_pre.get_topic(topic=0)
# Out:
# [('paris', 0.05615720044842678),
#  ('agreement', 0.03769333367947843),
#  ('accord', 0.029603085714951155),
#  ('president', 0.017190735459819386),
#  ('trump', 0.01658042089513091),
#  ('decision', 0.015128219779468556),
#  ('states', 0.013183347897855064),
#  ('united', 0.012892456219534377),
#  ('pull', 0.01288050350263076),
#  ('withdraw', 0.01241285834667872)]

# %%
# representative article for certain topic
topic_model_pre.get_representative_docs(0)
# Out:
# ['change made japan position g7 agreement important week trump international last climate uks signed clear paris leaders night president meeting canada',
#  'bring change afternoon us back thing accord one agreement important international climate think paris first get would rejoin day',
#  'change emissions trump paris described international us president accord agreement damaging gas reduce greenhouse hes withdrawing climate hoax']

# %%
topic_model_pre.visualize_topics()
# Out:
# <div>                            <div id="6e45c00a-c191-4340-a102-cf7b64465f23" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6e45c00a-c191-4340-a102-cf7b64465f23")) {                    Plotly.newPlot(                        "6e45c00a-c191-4340-a102-cf7b64465f23",                        [{"customdata":[[0,"paris | agreement | accord | president | trump",353],[1,"care | health | gun | immigration | issues",332],[2,"london | police | protests | protest | protesters",291],[3,"children | school | schools | kids | students",173],[4,"hurricane | hurricanes | storms | storm | irma",143],[5,"greta | thunberg | activist | swedish | teenage",126],[6,"australia | morrison | scott | prime | minister",121],[7,"bbc | news | glasgow | programme | mcgrath",120],[8,"warming | global | tweeted | cold | president",116],[9,"ice | glaciers | glacier | melt | antarctica",105],[10,"wildfires | california | fires | fire | wildfire",100],[11,"science | scientific | scientists | believe | overwhelming",99],[12,"weather | heatwave | heatwaves | temperatures | likely",82],[13,"gases | greenhouse | dioxide | atmosphere | gas",81],[14,"corbyn | election | jeremy | labour | party",76],[15,"president | trump | hes | trumps | administration",76],[16,"electric | cars | pollution | vehicles | diesel",73],[17,"pot | impacted | melting | touched | species",72],[18,"hoax | believes | president | believe | trump",71],[19,"cost | billions | money | dollars | economy",70],[20,"al | gore | film | inconvenient | sequel",69],[21,"zero | 2050 | uk | net | committee",65],[22,"jay | inslee | governor | washington | presidential",63],[23,"meat | dairy | beef | products | vegan",60],[24,"poland | conference | 200 | delegates | talks",59],[25,"soil | forest | trees | deforestation | farming",58],[26,"tax | carbon | taxes | economists | cap",57],[27,"iran | nuclear | differences | deal | trade",56],[28,"flying | aviation | heathrow | expand | restrict",56],[29,"humans | people | world | human | millions",51],[30,"attenborough | sir | david | broadcaster | warning",49],[31,"prince | charles | harry | duchess | duke",48],[32,"korea | north | nuclear | south | korean",48],[33,"coral | reef | barrier | reefs | bleaching",46],[34,"brazil | bolsonaro | amazon | brazils | rainforest",44],[35,"algae | keeps | potential | growing | half",44],[36,"senate | senators | mcconnell | republican | mitch",43],[37,"resilience | flooding | drought | floods | droughts",43],[38,"epa | pruitt | scott | administrator | head",42],[39,"debate | dnc | debates | stage | topic",41],[40,"republicans | democrats | republican | impeachment | party",41],[41,"security | threat | national | threats | states",40],[42,"coal | coalfired | power | energy | construction",39],[43,"obamas | executive | order | president | obama",38],[44,"food | agriculture | farming | eat | crop",38],[45,"film | bafta | propaganda | drama | awareness",37],[46,"sami | fish | finland | affecting | shetland",36],[47,"protesters | violent | police | tear | antigovernment",35],[48,"china | chinese | emitter | chinas | remarks",35],[49,"eu | europe | european | migration | migrants",34],[50,"sanders | bernie | senator | warren | trillion",34],[51,"white | house | testimony | written | hearing",33],[52,"g20 | summit | trade | 620 | leaders",33],[53,"oil | gas | rules | companies | scrapped",32],[54,"angela | merkel | chancellor | merkels | german",31],[55,"degrees | temperature | 15 | irreversible | celsius",31],[56,"miami | florida | orleans | water | island",27],[57,"greenhouse | methane | food | gases | animals",27],[58,"birds | arrive | starting | refuel | wintering",27],[59,"russia | russian | putin | vladimir | troubles",26],[60,"nancy | pelosi | speaker | pelosis | congresswoman",26],[61,"fossil ...

# %% [markdown]
# ## Tokenized Text

# %%
text_tok = media_20.Tokenized_Snippet.tolist()

# %%
topic_model_tok = BERTopic(embedding_model="all-MiniLM-L6-v2")

# %%
topics_tok, probs_tok = topic_model_tok.fit_transform(text_tok)

# %%
topic_model_tok.get_topic_info()
# Out:
#      Topic  Count                                               Name
# 0       -1   4946                   -1_climate_change_global_warming
# 1        0    344             0_australia_fires_wildfires_california
# 2        1    253                1_london_police_protests_protesters
# 3        2    230                2_care_health_immigration_democrats
# 4        3    180                  3_paris_agreement_accord_decision
# ..     ...    ...                                                ...
# 107    106     11     106_enhanced_commitments_implemented_agreement
# 108    107     11                 107_tucker_carlson_swamped_idiotic
# 109    108     11                     108_tomorrow_august_olivia_7th
# 110    109     11                109_brexit_labour_services_election
# 111    110     10  110_children_grandchildren_beautiful_childbearing
#
# [112 rows x 3 columns]

# %%
topic_model_tok.visualize_topics()
# Out:
# <div>                            <div id="c507a877-e75f-4c07-ab78-ce4961d55c19" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("