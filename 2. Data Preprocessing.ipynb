# %%
import pandas as pd

# %%
df = pd.read_csv('top100_climatechange.csv')

# %%
import nltk
from nltk.corpus import stopwords
import string

# Download NLTK stopwords and punkt
nltk.download('stopwords')
nltk.download('punkt')

# Define function to preprocess text
def preprocess_text(text):
    # Check if text is NaN
    if type(text) != str:
        return ""
    # Remove punctuation
    text = text.translate(str.maketrans('', '', string.punctuation))
    # Convert to lowercase
    text = text.lower()
    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    words = nltk.word_tokenize(text)
    words = [word for word in words if word not in stop_words]
    # Remove duplicates
    words = list(set(words))
    # Join words back into a string
    text = ' '.join(words)
    return text

# Replace missing values with an empty string
df['Text'] = df['Text'].fillna("")

# Apply preprocess_text function to the DataFrame
df['Preprocessed_Text'] = df['Text'].apply(preprocess_text)

# Print the cleaned DataFrame
print(df.head())
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/SimoneBroggini/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/SimoneBroggini/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
#                                                Title  \
# 0  I'm afraid climate change is going to kill me!...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                                 Text  \
# 0  Feeling scared? Have you been listening to or ...
# 1  Let's use this space to discuss some of the mo...
# 2  > Feeling scared? Have you been listening to o...
# 3  So I know this is a late response to this thre...
# 4  climate change isn't just going to pop up and ...
#
#                                    Preprocessed_Text
# 0  humanity listed httpswwwredditcomrclimatechang...
# 1  people original concerns make topics overall s...
# 2  reading think one change humanity climate vibe...
# 3  fix voting statement next viewpoint extraordin...
# 4  fix next exponentially plan geoengineer wasnt ...

# %%
df
# Out:
#                                                   Title  \
# 0     I'm afraid climate change is going to kill me!...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5070                                                NaN
# 5071                                                NaN
# 5072                                                NaN
# 5073                                                NaN
# 5074                                                NaN
#
#                                                    Text  \
# 0     Feeling scared? Have you been listening to or ...
# 1     Let's use this space to discuss some of the mo...
# 2     > Feeling scared? Have you been listening to o...
# 3     So I know this is a late response to this thre...
# 4     climate change isn't just going to pop up and ...
# ...                                                 ...
# 5070  Figure 30 has 100 MW installations at 0.94 per...
# 5071  There are lots of ways to reduce water lost to...
# 5072  Cyanide CN, carbon dioxide CO2. We can refer t...
# 5073  There was a study with a compound in both coff...
# 5074  Your link has a land cost of 3 cents per watt....
#
#                                       Preprocessed_Text
# 0     humanity listed httpswwwredditcomrclimatechang...
# 1     people original concerns make topics overall s...
# 2     reading think one change humanity climate vibe...
# 3     fix voting statement next viewpoint extraordin...
# 4     fix next exponentially plan geoengineer wasnt ...
# ...                                                 ...
# 5070  representation less land watt per study 100 ba...
# 5071  evaporation reduce lost expensive panel httpsw...
# 5072                dioxide co2 cn carbon cyanide refer
# 5073  800mg cocoa calcium less consuming loss compou...
# 5074  cost utility land watt cents link scale solar ...
#
# [5075 rows x 3 columns]
